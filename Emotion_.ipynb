# %% [markdown]
# # **Speech Emotion Recognition**
# Problem Statement: The objective of this project is to develop a robust speech emotion recognition system capable of accurately classifying the emotional states conveyed in spoken language. By analyzing the acoustic features of speech signals, the system should be able to categorize emotions such as happiness, sadness, anger, fear, and more.

# %% [markdown]
# # **Importing Libraries:**

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import IPython.display as ipd
import warnings
import tensorflow as tf
from keras import utils
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# # **Loading the Dataset:**

# %%
pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.8.30)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.5)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.8)

# %%
# !kaggle datasets download -d ejlok1/toronto-emotional-speech-set-tess
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ejlok1/toronto-emotional-speech-set-tess
# License(s): Attribution-NonCommercial-NoDerivatives 4.0 International (CC BY-NC-ND 4.0)
# Downloading toronto-emotional-speech-set-tess.zip to /content
#  98% 421M/428M [00:05<00:00, 81.9MB/s]
# 100% 428M/428M [00:06<00:00, 74.4MB/s]

# %%
 #Unzip the dataset
# !unzip toronto-emotional-speech-set-tess.zip -d /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_back_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_bar_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_base_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_bath_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_bean_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_beg_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_bite_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_boat_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_bone_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_book_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_bought_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_burn_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_cab_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_calm_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_came_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_cause_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_chain_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_chair_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_chalk_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_chat_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_check_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_cheek_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_chief_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_choice_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_cool_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_dab_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_date_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_dead_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_death_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_deep_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_dime_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_dip_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_ditch_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_dodge_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_dog_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_doll_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_door_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_fail_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_fall_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_far_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_fat_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_fit_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_five_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_food_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_gap_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_gas_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_gaze_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_germ_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_get_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_gin_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_goal_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_good_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_goose_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_gun_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_half_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_hall_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_hash_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_hate_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_have_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_haze_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_hire_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_hit_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_hole_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_home_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_hurl_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_hush_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_jail_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_jar_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_join_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_judge_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_jug_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_juice_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_keen_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_keep_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_keg_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_kick_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_kill_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_king_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_kite_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_knock_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_late_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_laud_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_lean_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_learn_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_lease_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_lid_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_life_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_limb_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_live_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_loaf_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_long_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_lore_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_lose_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_lot_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_love_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_luck_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_make_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_match_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_merge_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_mess_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_met_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_mill_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_mob_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_mode_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_mood_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_moon_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_mop_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_mouse_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_nag_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_name_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_near_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_neat_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_nice_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_note_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_numb_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_pad_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_page_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_pain_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_pass_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_pearl_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_peg_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_perch_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_phone_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_pick_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_pike_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_pole_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_pool_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_puff_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_rag_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_raid_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_rain_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_raise_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_rat_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_reach_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_read_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_red_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_ring_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_ripe_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_road_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_room_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_rose_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_rot_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_rough_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_rush_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_said_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_sail_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_search_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_seize_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_sell_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_shack_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_shall_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_shawl_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_sheep_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_shirt_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_should_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_shout_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_size_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_soap_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_soup_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_sour_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_south_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_sub_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_such_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_sure_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_take_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_talk_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_tape_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_team_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_tell_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_thin_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_third_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_thought_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_thumb_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_time_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_tip_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_tire_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_ton_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_tool_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_tough_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_turn_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_vine_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_voice_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_void_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_vote_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_wag_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_walk_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_wash_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_week_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_wheat_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_when_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_which_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_whip_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_white_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_wife_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_wire_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_witch_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_yearn_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_yes_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_young_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_angry/OAF_youth_angry.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_disgust/OAF_back_disgust.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_disgust/OAF_bar_disgust.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_disgust/OAF_base_disgust.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_disgust/OAF_bath_disgust.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_disgust/OAF_bean_disgust.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_disgust/OAF_beg_disgust.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_disgust/OAF_bite_disgust.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_disgust/OAF_boat_disgust.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_disgust/OAF_bone_disgust.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_disgust/OAF_book_disgust.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_disgust/OAF_bought_disgust.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_disgust/OAF_burn_disgust.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_disgust/OAF_cab_disgust.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_disgust/OAF_calm_disgust.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_disgust/OAF_came_disgust.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_disgust/OAF_cause_disgust.wav
#   inflating: /content/TESS Toronto emotional speech set data/OAF_disgust/OAF
sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_late_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_laud_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_lean_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_learn_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_lease_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_lid_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_life_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_limb_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_live_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_loaf_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_long_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_lore_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_lose_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_lot_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_love_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_luck_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_make_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_match_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_merge_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_mess_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_met_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_mill_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_mob_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_mode_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_mood_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_moon_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_mop_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_mouse_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_nag_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_name_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_near_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_neat_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_nice_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_note_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_numb_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pad_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_page_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pain_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pass_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pearl_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_peg_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_perch_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_phone_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pick_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pike_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pole_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pool_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_puff_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_rag_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_raid_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_rain_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_raise_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_rat_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_reach_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_read_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_red_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_ring_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_ripe_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_road_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_room_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_rose_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_rot_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_rough_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_rush_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_said_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_sail_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_search_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_seize_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_sell_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_shack_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_shall_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_shawl_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_sheep_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_shirt_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_should_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_shout_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_size_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_soap_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_soup_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_sour_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_south_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_sub_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_such_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_sure_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_take_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_talk_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_tape_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_team_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_tell_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_thin_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_third_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_thought_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_thumb_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_time_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_tip_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_tire_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_ton_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_tool_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_tough_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_turn_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_vine_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_voice_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_void_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_vote_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_wag_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_walk_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_wash_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_week_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_wheat_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_when_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_which_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_whip_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_white_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_wife_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_wire_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_witch_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_yearn_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_yes_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_young_sad.wav
#   inflating: /content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_youth_sad.wav

# %%
paths = []
labels = []

data_dir = '/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data'
for dirname, _, filenames in os.walk(data_dir):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
    if len(paths) == 2800:
        break
print('Dataset is Loaded')
# Out:
# Dataset is Loaded

# %%
paths[:10]
# Out:
# ['/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Fear/OAF_make_fear.wav',
#  '/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Fear/OAF_tough_fear.wav',
#  '/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Fear/OAF_join_fear.wav',
#  '/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Fear/OAF_wife_fear.wav',
#  '/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Fear/OAF_nag_fear.wav',
#  '/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Fear/OAF_time_fear.wav',
#  '/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Fear/OAF_read_fear.wav',
#  '/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Fear/OAF_base_fear.wav',
#  '/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Fear/OAF_gun_fear.wav',
#  '/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Fear/OAF_came_fear.wav']

# %%
len(paths)
# Out:
# 2800

# %%
labels[:10]
# Out:
# ['fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear']

# %% [markdown]
# # **Creating DataFrame for Speech Data and Labels:**

# %%
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels
df.head()
# Out:
#                                               speech label
# 0  /content/tess toronto emotional speech set dat...  fear
# 1  /content/tess toronto emotional speech set dat...  fear
# 2  /content/tess toronto emotional speech set dat...  fear
# 3  /content/tess toronto emotional speech set dat...  fear
# 4  /content/tess toronto emotional speech set dat...  fear

# %% [markdown]
# # **Counting Labels:**

# %%
df['label'].value_counts()
# Out:
# label
# fear       400
# ps         400
# happy      400
# disgust    400
# sad        400
# angry      400
# neutral    400
# Name: count, dtype: int64

# %% [markdown]
# # EDA [Explory Data Analysis]

# %%
sns.countplot(x = df['label'], data=df, palette='dark')
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %% [markdown]
# # **Loading and Playing Audio Data:**

# %%
data, sampling_rate = librosa.load('/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Fear/OAF_make_fear.wav')
ipd.Audio('/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_Fear/OAF_make_fear.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # **Visualizing Audio Waveform:**

# %%
plt.figure(figsize=(18, 6))
librosa.display.waveshow(data, sr=sampling_rate)

# %% [markdown]
# # Custom Functions for Audio Visualization

# %%
def waveplot(data, sr, emotion):
    plt.figure(figsize=(10,4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()

def spectogram(data, sr, emotion):
    x = librosa.stft(data)
    x_db = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(x_db, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

# %% [markdown]
# # Fear Label Emotion Speech Analysis:

# %%
emotion = 'fear'
path = np.array(df['speech'][df['label']==emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # PS Label Emotion Speech Analysis:

# %%
emotion = 'ps'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Happy Label Emotion Speech Analysis:

# %%
emotion = 'happy'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Disgust Label Emotion Speech Analysis:

# %%
emotion = 'disgust'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Sad Label Emotion Speech Analysis:

# %%
emotion = 'sad'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Angry Label Emotion Speech Analysis:

# %%
emotion = 'angry'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Neutral Label Emotion Speech Analysis:

# %%
emotion = 'neutral'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Pie Chart: Emotion Distribution

# %%
labels = ["fear", "angry", "disgust", "neutral", "sad","ps", "happy"]
plt.pie(df['label'].value_counts(), labels = labels, autopct = '%.0f%%', radius= 2, textprops={'fontsize': 16})
plt.show()

# %% [markdown]
# # **Feature Extraction using MFCC (Mel-frequency cepstral coefficients):**

# %%
def feature_extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    return np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)

# %%
feature_extract_mfcc(df['speech'][0])
# Out:
# array([-4.2161575e+02,  7.1886749e+01,  3.4655268e+00, -1.2595891e+00,
#         6.9849730e+00,  1.1855711e+00, -2.3669140e+01, -3.9480424e+00,
#        -1.2947012e+01, -1.1110929e+01, -1.5398541e+01, -8.0095921e+00,
#        -5.5294638e+00,  3.4246867e+00, -1.3583757e+01, -2.6401592e-02,
#        -9.3942517e-01, -5.4312544e+00,  1.1645808e+00, -5.8925781e+00,
#         1.4299470e+00,  2.2986536e+01,  2.0962997e+01,  3.1096960e+01,
#         2.3955347e+01,  2.0585012e+01, -3.4647304e-01,  5.0551200e+00,
#        -3.5828719e+00,  8.4885311e+00,  9.4356215e-01, -2.2265260e+00,
#        -1.2476732e+00, -3.3232660e+00,  1.8594933e+00,  1.8838865e+00,
#        -7.2334237e+00,  4.5912361e-01, -4.9244771e+00,  2.3670096e+00],
#       dtype=float32)

# %%
MFCC = df['speech'].apply(lambda x: feature_extract_mfcc(x))
MFCC
# Out:
# 0       [-421.61575, 71.88675, 3.4655268, -1.2595891, ...
# 1       [-454.8798, 75.199585, 6.9619513, -14.120413, ...
# 2       [-439.6242, 62.804733, 4.6470737, -0.054180752...
# 3       [-425.9018, 58.18295, 10.552817, -22.733334, -...
# 4       [-449.04416, 92.0742, 3.0549376, -22.166662, 4...
#                               ...
# 2795    [-249.57428, 49.819122, -32.97859, 20.480375, ...
# 2796    [-337.37106, 79.9122, -8.179246, -6.7097054, -...
# 2797    [-351.9943, 65.76154, -3.007033, 6.5676017, -3...
# 2798    [-368.90167, 46.88164, -6.6126623, 21.814884, ...
# 2799    [-340.2761, 74.7377, -26.830662, 15.027941, -2...
# Name: speech, Length: 2800, dtype: object

# %%
X=[x for x in MFCC]
X=np.array(X)
X.shape
# Out:
# (2800, 40)

# %%
X=np.expand_dims(X,-1)
X.shape
# Out:
# (2800, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
y = encoder.fit_transform(df[['label']])
y= y.toarray()

# %%
y.shape
# Out:
# (2800, 7)

# %% [markdown]
# # **Splitting Data into Training and Testing Sets**

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(X,y, test_size= 0.20, random_state = 30)

# %% [markdown]
# # Creating a Speech Emotion Recognition Model using LSTM

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(256, return_sequences=False, input_shape=(40,1)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
    ])
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                        │ (None, 256)                 │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 7)                   │             455 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 305,799 (1.17 MB)
#  Trainable params: 305,799 (1.17 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # **Training the model**

# %%
history = model.fit(x_train,y_train, validation_split=0.2, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 190ms/step - accuracy: 0.3548 - loss: 1.6170 - val_accuracy: 0.6741 - val_loss: 0.7090
# Epoch 2/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 191ms/step - accuracy: 0.6969 - loss: 0.7495 - val_accuracy: 0.8817 - val_loss: 0.3342
# Epoch 3/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 239ms/step - accuracy: 0.8716 - loss: 0.3892 - val_accuracy: 0.9420 - val_loss: 0.1993
# Epoch 4/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 168ms/step - accuracy: 0.9173 - loss: 0.2290 - val_accuracy: 0.9509 - val_loss: 0.1384
# Epoch 5/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 229ms/step - accuracy: 0.9363 - loss: 0.2056 - val_accuracy: 0.9397 - val_loss: 0.1863
# Epoch 6/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 9s 176ms/step - accuracy: 0.9299 - loss: 0.2173 - val_accuracy: 0.9219 - val_loss: 0.2073
# Epoch 7/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9471 - loss: 0.1685 - val_accuracy: 0.9286 - val_loss: 0.1851
# Epoch 8/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 172ms/step - accuracy: 0.9549 - loss: 0.1436 - val_accuracy: 0.9665 - val_loss: 0.1246
# Epoch 9/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9709 - loss: 0.0942 - val_accuracy: 0.9777 - val_loss: 0.0772
# Epoch 10/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 9s 170ms/step - accuracy: 0.9628 - loss: 0.0999 - val_accuracy: 0.8661 - val_loss: 0.4443
# Epoch 11/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9177 - loss: 0.2714 - val_accuracy: 0.9286 - val_loss: 0.2042
# Epoch 12/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - accuracy: 0.9673 - loss: 0.1046 - val_accuracy: 0.9665 - val_loss: 0.1130
# Epoch 13/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.9718 - loss: 0.0978 - val_accuracy: 0.9710 - val_loss: 0.0928
# Epoch 14/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 9s 327ms/step - accuracy: 0.9665 - loss: 0.0949 - val_accuracy: 0.9777 - val_loss: 0.0587
# Epoch 15/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 167ms/step - accuracy: 0.9817 - loss: 0.0594 - val_accuracy: 0.9821 - val_loss: 0.0653
# Epoch 16/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 0.9742 - loss: 0.0643 - val_accuracy: 0.9688 - val_loss: 0.0952
# Epoch 17/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s
50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9807 - loss: 0.0481 - val_accuracy: 0.9777 - val_loss: 0.0854
# Epoch 43/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 175ms/step - accuracy: 0.9837 - loss: 0.0393 - val_accuracy: 0.9754 - val_loss: 0.0889
# Epoch 44/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - accuracy: 0.9908 - loss: 0.0279 - val_accuracy: 0.9888 - val_loss: 0.0410
# Epoch 45/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 264ms/step - accuracy: 0.9891 - loss: 0.0380 - val_accuracy: 0.9777 - val_loss: 0.0854
# Epoch 46/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 166ms/step - accuracy: 0.9734 - loss: 0.0915 - val_accuracy: 0.9799 - val_loss: 0.0909
# Epoch 47/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9930 - loss: 0.0205 - val_accuracy: 0.9844 - val_loss: 0.0574
# Epoch 48/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 170ms/step - accuracy: 0.9937 - loss: 0.0181 - val_accuracy: 0.9888 - val_loss: 0.0260
# Epoch 49/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9988 - loss: 0.0052 - val_accuracy: 0.9888 - val_loss: 0.0409
# Epoch 50/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 167ms/step - accuracy: 0.9990 - loss: 0.0066 - val_accuracy: 0.9933 - val_loss: 0.0340

# %% [markdown]
# # **Ploting the results**

# %%
epochs = list(range(50))
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

plt.plot(epochs, accuracy, label='train accuracy')
plt.plot(epochs, val_accuracy, label='validation accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
model.evaluate(x_train , y_train)
# Out:
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.9999 - loss: 0.0017
# [0.007812050636857748, 0.9986607432365417]

# %%
y_pred = model.predict(x_test, batch_size=5)
# Out:
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step

# %%
accuracy_score=model.evaluate(x_test , y_test)
print ("Model evaluation accuracy: ", round(accuracy_score[1]*100),"%")
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9873 - loss: 0.0547
# Model evaluation accuracy:  99 %

# %% [markdown]
# # Saving the Trained Model

# %%
import os

# Get the current working directory
current_dir = os.getcwd()
print("Current directory:", current_dir)

save_dir = "Speech Emotion Recognition Project"
os.makedirs(save_dir, exist_ok=True)

model_file = os.path.join(save_dir, "content/tess toronto emotional speech set data/TESS Toronto emotional speech set data.h5")
# Out:
# Current directory: /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model.save('Speech Emotion Recognition Project/model.keras')

# %%
model.save("Trained_model.keras")
model.save("Trained_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save('/content/drive/MyDrive/Saving Moduel/model.keras') # Adds the .keras extension to the filepath, saving the model in the recommended Keras format.

# %%
model_name = 'emotion_speech_recognition_model_lstm.h5'
save_dir = os.path.join(os.getcwd(), 'train_model')

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save('/content/train_model/emotion_speech_recognition_model_lstm.keras')
print('Saved the trained model at %s ' % model_path)
# Out:
# Saved the trained model at /content/train_model/emotion_speech_recognition_model_lstm.h5

# %% [markdown]
# # **Saving the Model Architecture as JSON**

# %%
import json
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)

# %% [markdown]
# # **Loading the Trained Model from JSON and Weights**

# %%
from keras.models import model_from_json
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)

loaded_model.load_weights("/content/train_model/emotion_speech_recognition_model_lstm.h5")
print("Loaded model from disk")

loaded_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
score = loaded_model.evaluate(x_test, y_test, verbose=0)
print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))
# Out:
# Loaded model from disk
# compile_metrics: 97.50%

# %% [markdown]
# # Predicting Emotions using the Loaded Model

# %%
pred = loaded_model.predict(x_test, batch_size=32, verbose=1)
pred
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# array([[9.8671788e-01, 6.8701549e-05, 4.5434426e-05, ..., 1.6425782e-05,
#         1.3117488e-02, 1.4406961e-05],
#        [3.9593899e-03, 3.7535259e-03, 3.6023124e-05, ..., 1.7729435e-05,
#         9.9147868e-01, 1.2555458e-05],
#        [2.6725447e-05, 9.9852902e-01, 1.0485355e-07, ..., 8.0219394e-08,
#         1.2177543e-04, 1.3033045e-03],
#        ...,
#        [9.1841015e-05, 5.5233145e-04, 2.5715710e-07, ..., 6.0261004e-06,
#         5.0928524e-05, 9.9925888e-01],
#        [3.4653790e-06, 1.1970292e-07, 1.2875611e-06, ..., 8.4551671e-11,
#         5.9060512e-06, 4.1593630e-08],
#        [9.9804968e-01, 1.5405261e-04, 2.0431469e-05, ..., 9.0707426e-06,
#         1.7301334e-03, 2.9283199e-05]], dtype=float32)

# %%
_pred=pred.argmax(axis=1)
_pred
# Out:
# array([0, 5, 1, 0, 1, 3, 5, 4, 3, 4, 6, 0, 1, 1, 3, 5, 0, 1, 4, 6, 1, 0,
#        5, 0, 6, 3, 3, 0, 0, 2, 1, 0, 2, 3, 1, 0, 1, 3, 6, 4, 5, 3, 5, 3,
#        5, 4, 3, 6, 2, 1, 4, 4, 5, 3, 5, 0, 4, 4, 3, 2, 6, 4, 3, 5, 5, 4,
#        1, 4, 4, 5, 3, 6, 2, 0, 0, 0, 3, 0, 5, 3, 4, 3, 0, 6, 3, 6, 4, 1,
#        6, 6, 1, 3, 5, 0, 3, 4, 3, 2, 1, 0, 3, 0, 2, 2, 0, 3, 6, 6, 3, 0,
#        1, 2, 6, 6, 4, 6, 4, 5, 5, 0, 1, 4, 6, 3, 6, 2, 3, 5, 1, 1, 4, 3,
#        3, 6, 1, 1, 3, 4, 5, 3, 5, 2, 6, 5, 4, 6, 0, 3, 4, 2, 2, 2, 1, 6,
#        2, 0, 3, 1, 3, 1, 1, 2, 4, 1, 5, 3, 4, 0, 3, 6, 0, 0, 1, 4, 6, 3,
#        5, 3, 4, 3, 4, 1, 3, 6, 5, 0, 4, 0, 1, 2, 6, 0, 1, 4, 4, 6, 3, 4,
#        5, 5, 0, 5, 1, 5, 1, 4, 3, 4, 1, 6, 4, 3, 3, 5, 6, 4, 1, 3, 1, 5,
#        1, 0, 3, 2, 1, 6, 5, 1, 0, 3, 0, 1, 0, 5, 6, 6, 5, 5, 0, 4, 4, 5,
#        3, 3, 1, 0, 4, 2, 4, 6, 0, 5, 1, 2, 1, 3, 3, 5, 4, 5, 2, 4, 5, 4,
#        6, 1, 3, 5, 3, 6, 5, 6, 5, 5, 1, 3, 3, 1, 4, 3, 2, 4, 6, 2, 2, 0,
#        4, 6, 6, 0, 2, 5, 5, 1, 5, 3, 4, 4, 6, 1, 3, 6, 4, 3, 6, 3, 5, 2,
#        0, 4, 2, 2, 2, 6, 0, 4, 2, 6, 5, 3, 0, 3, 0, 0, 2, 2, 1, 5, 2, 2,
#        3, 2, 6, 0, 0, 4, 1, 0, 4, 4, 3, 5, 0, 0, 6, 5, 1, 3, 5, 2, 6, 1,
#        4, 5, 6, 6, 5, 0, 3, 3, 5, 2, 0, 1, 4, 6, 1, 6, 1, 2, 0, 1, 4, 3,
#        1, 5, 4, 5, 6, 5, 0, 1, 6, 0, 0, 6, 5, 6, 2, 6, 2, 3, 6, 3, 4, 6,
#        6, 1, 4, 3, 4, 5, 3, 1, 2, 4, 6, 1, 2, 3, 2, 3, 4, 5, 4, 0, 1, 1,
#        4, 4, 0, 5, 4, 0, 3, 2, 6, 6, 2, 5, 0, 6, 0, 0, 3, 5, 6, 1, 1, 3,
#        6, 2, 4, 0, 1, 6, 1, 6, 4, 0, 0, 3, 4, 1, 4, 0, 6, 5, 3, 6, 2, 5,
#        0, 0, 3, 6, 4, 5, 5, 1, 0, 2, 2, 2, 6, 0, 1, 5, 3, 2, 4, 6, 3, 0,
#        2, 2, 0, 0, 0, 4, 2, 5, 2, 1, 4, 6, 6, 2, 3, 3, 4, 4, 5, 6, 1, 1,
#        1, 3, 4, 3, 6, 0, 0, 5, 3, 5, 2, 4, 3, 5, 3, 3, 1, 2, 2, 6, 3, 3,
#        1, 0, 2, 5, 6, 0, 2, 2, 4, 3, 6, 6, 0, 6, 4, 1, 0, 4, 6, 2, 6, 6,
#        0, 3, 6, 3, 1, 0, 5, 6, 3, 0])

# %%
z = _pred.astype(int).flatten()
prediction = (encoder.inverse_transform(z.reshape(-1, 7)))
pred_data = pd.DataFrame({'Predicted Values': prediction.flatten()})
pred_data[:10]
# Out:
#   Predicted Values
# 0          disgust
# 1            happy
# 2               ps
# 3            happy
# 4               ps
# 5            happy
# 6               ps
# 7            happy
# 8          neutral
# 9            angry

# %% [markdown]
# # Displaying Predicted Emotions for Test Data

# %%
actual=y_test.argmax(axis=1)
yz = actual.astype(int).flatten()
actual_values = (encoder.inverse_transform((yz.reshape(-1, 7))))
actual_data = pd.DataFrame({'actual values': actual_values.flatten()})
actual_data[:10]
# Out:
#   actual values
# 0       disgust
# 1         happy
# 2            ps
# 3         happy
# 4            ps
# 5         happy
# 6            ps
# 7         happy
# 8       neutral
# 9         angry

# %%
final_data = actual_data.join(pred_data)

# %% [markdown]
# # **Actual vs Predicted Emotions**

# %%
final_data[:15]
# Out:
#    actual values Predicted Values
# 0        disgust          disgust
# 1          happy            happy
# 2             ps               ps
# 3          happy            happy
# 4             ps               ps
# 5          happy            happy
# 6             ps               ps
# 7          happy            happy
# 8        neutral          neutral
# 9          angry            angry
# 10       disgust          disgust
# 11           sad              sad
# 12       disgust          disgust
# 13       disgust          disgust
# 14          fear             fear

# %%
final_data.groupby('Predicted Values').count()
# Out:
#                   actual values
# Predicted Values
# angry                        18
# disgust                      15
# fear                         10
# happy                        12
# neutral                       7
# ps                           11
# sad                           7

# %% [markdown]
# # **Visualizing Confusion Matrix**

# %%
from sklearn.metrics import confusion_matrix
emotions = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'ps', 'sad']

cm = confusion_matrix(actual_data, pred_data)

cm_df = pd.DataFrame(cm, index=emotions, columns=emotions)

plt.figure(figsize=(8, 6))
sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
